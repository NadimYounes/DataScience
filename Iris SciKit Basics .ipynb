# %%
from sklearn import datasets
from matplotlib import pyplot as plt
import numpy as np
# %pylab inline
iris = datasets.load_iris()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# X= Features (independent)
#Y = Outcome (Dependent)
X = iris.data
y = iris.target

# %%
#Supervised clustering problem with a categorical outcome- preferred model would be a classifier
#Import model
from sklearn.neighbors import KNeighborsClassifier
#Make an instance
knn = KNeighborsClassifier(n_neighbors=5)
#Fit 
knn.fit(x, y)
#Predict
pred_1 = knn.predict(x)
len(pred_1)
print(metrics.accuracy_score(y,pred_1)*100)
# Out:
# 96.66666666666667

# %%
# Try out different values for n to visualize the effects of bias overfitting and underfitting 
accuracy_scores = []
i_range = range(1,50)
for i in i_range:
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x, y)
    pred = knn.predict(x)
    accuracy_scores.append(metrics.accuracy_score(y,pred))

plt.plot(i_range,accuracy_scores)
plt.ylabel('accuracy_scores')
plt.xlabel('n_neighbors')
# Out:
# Text(0.5,0,'n_neighbors')

# %%
#Repeat with a train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=4)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
pred_2 = knn.predict(x_test)
print(metrics.accuracy_score(y_test,pred_2))
# Out:
# 0.9777777777777777

# %%
# Try out different values for size of training set 
#As training set increases, the model has more points to work with so accuracy starts to go up.
accuracy_scores2 = []
testsize_range = np.arange(0.1,1,0.1)

for i in testsize_range:
    x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=i, random_state=4)
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(x_train, y_train)
    pred_2 = knn.predict(x_test)
    accuracy_scores2.append(metrics.accuracy_score(y_test,pred_2))


plt.plot(testsize_range, accuracy_scores2)
# Out:
# /Users/nadimyounes/anaconda3/lib/python3.5/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
